# %%
import DTW_utils as utils
import DTW
import pandas as pd
# Out:
# <module 'posixpath' (frozen)>

# %%
train_pages = pd.read_csv("train.tsv", sep="\t", header=None, names=["image_nr"])

# %%
train = train_pages[1:]

# %%
train_images = {}   # loc → cropped image

for page in train['image_nr']:
    words = utils.extract_word_images(page)
    for img, poly, loc in words:
        train_images[loc] = img
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 train_images = {}   # loc → cropped image
#       3 for page in train:
# ----> 4     words = utils.extract_word_images(page)
#       5     for img, poly, loc in words:
#       6         train_images[loc] = img
#
# File ~/Desktop/HS2025/ML/PR_group7/KWS/DTW_utils.py:84, in extract_word_images(image_nr, return_format)
#      81 image_path = f"KWS/images/{image_nr}.jpg"
#      82 svg_path = f"locations/{image_nr}.svg"
# ---> 84 image = Image.open(image_path).convert("RGB")
#      85 width, height = image.size
#      87 # Parse SVG
#
# File ~/Desktop/HS2025/ML/PR_group7/.venv/lib/python3.11/site-packages/PIL/Image.py:3493, in open(fp, mode, formats)
#    3491 if is_path(fp):
#    3492     filename = os.fspath(fp)
# -> 3493     fp = builtins.open(filename, "rb")
#    3494     exclusive_fp = True
#    3495 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'KWS/images/image_nr.jpg'
