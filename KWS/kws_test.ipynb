# %%
import DTW_utils as utils
import DTW
import pandas as pd
# Out:
# <module 'posixpath' (frozen)>

# %%
transcriptions = pd.read_csv("transcription.tsv", delimiter="\t", header=None)
transcriptions.columns = ["loc", "word"]

transcription_dict = dict(zip(transcriptions["loc"], transcriptions["word"]))

# %%
train_pages = pd.read_csv("train.tsv", sep="\t", header=None, names=["image_nr"])

# %%
# skip first page, since num doc_nrs != polygones 
train_pages = train_pages[1:]

# %%
train_db = []
train_images = {} # cropped images 

for page in train_pages['image_nr']:
    words = utils.extract_word_images(page)

    for img, poly, loc in words:
        # images
        train_images[loc] = img

        # transcriptiom
        transcription = transcription_dict[loc]

        # Preprocessing & Features
        img_prep = utils.preprocess_img(img)
        feat = utils.extract_features(img_prep)

        train_db.append({
            "loc": loc,
            "word": transcription,
            "features": feat
        })
# Out:
# length doc_nrs 274
# length polygons 274
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 5
#       2 train_images = {} # cropped images
#       4 for page in train_pages['image_nr']:
# ----> 5     words = utils.extract_word_images(page)
#       7     for img, poly, loc in words:
#       8         # images
#       9         train_images[loc] = img
#
# File ~/Desktop/HS2025/ML/PR_group7/KWS/DTW_utils.py:126, in extract_word_images(image_nr, return_format)
#     123 img_np = np.array(image)
#     124 img_np[mask_np == 0] = (255, 255, 255)  # background -> white
# --> 126 x_min, y_min = points.min(axis=0)
#     127 x_max, y_max = points.max(axis=0)
#     128 crop = img_np[int(y_min):int(y_max), int(x_min):int(x_max)]
#
# File ~/Desktop/HS2025/ML/PR_group7/.venv/lib/python3.11/site-packages/numpy/core/_methods.py:43, in _amin(a, axis, out, keepdims, initial, where)
#      39 def _amax(a, axis=None, out=None, keepdims=False,
#      40           initial=_NoValue, where=True):
#      41     return umr_maximum(a, axis, None, out, keepdims, initial, where)
# ---> 43 def _amin(a, axis=None, out=None, keepdims=False,
#      44           initial=_NoValue, where=True):
#      45     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
#
# KeyboardInterrupt:

# %%
import os
import pickle

os.makedirs("train_words", exist_ok=True)

for loc, img in train_images.items():
    filename = f"train_words/{loc}.png"
    img.save(filename)


os.makedirs("train_features", exist_ok=True)

with open("train_features/train_db.pkl", "wb") as f:
    pickle.dump(train_db, f)

# %%
valindatio_pages = pd.read_csv('validation.tsv', sep="\t", header=None, names=["image_nr"])
# Out:
#   Cell In[1], line 1
#     valindatio_pages = pd.read_csv('validation.tsv', sep="\t", header=None, names=["image_nr"]) )
#                                                                                                 ^
# SyntaxError: unmatched ')'
