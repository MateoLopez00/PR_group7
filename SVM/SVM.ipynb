# %%
import sys
from pathlib import Path
sys.path.append(str(Path().resolve().parent))  # eine Ebene hoch auf project/
import utils.data_loader as data_loader
import pandas as pd
import numpy as np  
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.model_selection import RandomizedSearchCV

# %%
# load train dataset 

X_train, y_train = data_loader.get_training_data()

# %%
# create random subset of 15000 examples to optimize hyperparameters 
X_sub, _, y_sub, _ = train_test_split(
    X_train, y_train,
    train_size=15000,
    stratify=y_train,     # wichtig bei Klassifikationsproblemen
    random_state=42
)

# %%
C_range = [0.1, 1, 10, 100, 1000] 
gamma_range = [1, 0.1, 0.01, 0.001, 0.0001] 
kernels = ['linear', 'rbf'] 
param_dist = [ 
    {'kernel': ['linear'], 'C': C_range}, 
    {'kernel': ['rbf'], 'C': C_range, 'gamma': gamma_range} 
    ]

random_search = RandomizedSearchCV(SVC(random_state=42), param_dist, n_iter=25, refit=True, cv=5, verbose=10, n_jobs=-1, random_state=42)
random_search.fit(X_sub,y_sub)

results = random_search.cv_results_
df_results = pd.DataFrame(results)
df_results.to_csv("random_search_results.csv", index=False)
print(f'The best parameter is {random_search.best_params_}')
print(f'The best score is {random_search.best_score_}')
print(f'The best estimator {random_search.best_estimator_}')
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5; 1/25] START C=1000, gamma=0.01, kernel=rbf.............................
# [CV 4/5; 1/25] START C=1000, gamma=0.01, kernel=rbf.............................
# [CV 5/5; 1/25] START C=1000, gamma=0.01, kernel=rbf.............................
# [CV 3/5; 1/25] START C=1000, gamma=0.01, kernel=rbf.............................
# [CV 1/5; 2/25] START C=10, gamma=1, kernel=rbf..................................
# [CV 3/5; 2/25] START C=10, gamma=1, kernel=rbf..................................
# [CV 2/5; 1/25] START C=1000, gamma=0.01, kernel=rbf.............................
# [CV 2/5; 2/25] START C=10, gamma=1, kernel=rbf..................................
# [CV 1/5; 1/25] END C=1000, gamma=0.01, kernel=rbf;, score=0.962 total time= 2.0min
# [CV 4/5; 2/25] START C=10, gamma=1, kernel=rbf..................................
# [CV 5/5; 1/25] END C=1000, gamma=0.01, kernel=rbf;, score=0.964 total time= 2.0min
# [CV 4/5; 1/25] END C=1000, gamma=0.01, kernel=rbf;, score=0.964 total time= 2.0min
# [CV 5/5; 2/25] START C=10, gamma=1, kernel=rbf..................................
# [CV 1/5; 3/25] START C=100, gamma=0.001, kernel=rbf.............................
# [CV 2/5; 1/25] END C=1000, gamma=0.01, kernel=rbf;, score=0.971 total time= 2.0min
# [CV 2/5; 3/25] START C=100, gamma=0.001, kernel=rbf.............................
# [CV 3/5; 1/25] END C=1000, gamma=0.01, kernel=rbf;, score=0.964 total time= 2.0min
# [CV 3/5; 3/25] START C=100, gamma=0.001, kernel=rbf.............................
# [CV 1/5; 3/25] END C=100, gamma=0.001, kernel=rbf;, score=0.944 total time= 1.6min
# [CV 4/5; 3/25] START C=100, gamma=0.001, kernel=rbf.............................
# [CV 2/5; 3/25] END C=100, gamma=0.001, kernel=rbf;, score=0.947 total time= 1.6min
# [CV 5/5; 3/25] START C=100, gamma=0.001, kernel=rbf.............................
# [CV 3/5; 3/25] END C=100, gamma=0.001, kernel=rbf;, score=0.947 total time= 1.6min
# [CV 1/5; 4/25] START C=10, gamma=0.01, kernel=rbf...............................
# [CV 4/5; 3/25] END C=100, gamma=0.001, kernel=rbf;, score=0.945 total time= 1.6min
# [CV 2/5; 4/25] START C=10, gamma=0.01, kernel=rbf...............................
# [CV 5/5; 3/25] END C=100, gamma=0.001, kernel=rbf;, score=0.938 total time= 1.6min
# [CV 3/5; 4/25] START C=10, gamma=0.01, kernel=rbf...............................
# [CV 1/5; 4/25] END C=10, gamma=0.01, kernel=rbf;, score=0.963 total time= 2.0min
# [CV 4/5; 4/25] START C=10, gamma=0.01, kernel=rbf...............................
# [CV 2/5; 4/25] END C=10, gamma=0.01, kernel=rbf;, score=0.971 total time= 2.1min
# [CV 5/5; 4/25] START C=10, gamma=0.01, kernel=rbf...............................
# [CV 3/5; 4/25] END C=10, gamma=0.01, kernel=rbf;, score=0.965 total time= 2.1min
# [CV 1/5; 5/25] START C=0.1, gamma=0.001, kernel=rbf.............................
# [CV 4/5; 4/25] END C=10, gamma=0.01, kernel=rbf;, score=0.965 total time= 2.1min
# [CV 2/5; 5/25] START C=0.1, gamma=0.001, kernel=rbf.............................
# [CV 5/5; 4/25] END C=10, gamma=0.01, kernel=rbf;, score=0.964 total time= 2.0min
# [CV 3/5; 5/25] START C=0.1, gamma=0.001, kernel=rbf.............................
# [CV 3/5; 2/25] END ...C=10, gamma=1, kernel=rbf;, score=0.180 total time=15.2min
# [CV 4/5; 5/25] START C=0.1, gamma=0.001, kernel=rbf.............................
# [CV 2/5; 2/25] END ...C=10, gamma=1, kernel=rbf;, score=0.181 total time=15.3min
# [CV 5/5; 5/25] START C=0.1, gamma=0.001, kernel=rbf.............................
# [CV 1/5; 2/25] END ...C=10, gamma=1, kernel=rbf;, score=0.179 total time=16.0min
# [CV 1/5; 6/25] START C=0.1, gamma=0.0001, kernel=rbf............................
# [CV 1/5; 5/25] END C=0.1, gamma=0.001, kernel=rbf;, score=0.855 total time= 9.3min
# [CV 2/5; 6/25] START C=0.1, gamma=0.0001, kernel=rbf............................
# [CV 2/5; 5/25] END C=0.1, gamma=0.001, kernel=rbf;, score=0.854 total time= 9.2min
# [CV 3/5; 6/25] START C=0.1, gamma=0.0001, kernel=rbf............................
# [CV 5/5; 2/25] END ...C=10, gamma=1, kernel=rbf;, score=0.178 total time=15.5min
# [CV 4/5; 6/25] START C=0.1, gamma=0.0001, kernel=rbf............................
# [CV 4/5; 2/25] END ...C=10, gamma=1, kernel=rbf;, score=0.181 total time=15.6min
# [CV 5/5; 6/25] START C=0.1, gamma=0.0001, kernel=rbf............................
# [CV 3/5; 5/25] END C=0.1, gamma=0.001, kernel=rbf;, score=0.858 total time= 9.1min
# [CV 1/5; 7/25] START C=1000, gamma=0.001, kernel=rbf............................
# [CV 1/5; 7/25] END C=1000, gamma=0.001, kernel=rbf;, score=0.941 total time= 1.5min
# [CV 2/5; 7/25] START C=1000, gamma=0.001, kernel=rbf............................
# [CV 2/5; 7/25] END C=1000, gamma=0.001, kernel=rbf;, score=0.944 total time= 1.6min
# [CV 3/5; 7/25] START C=1000, gamma=0.001, kernel=rbf............................
# [CV 3/5; 7/25] END C=1000, gamma=0.001, kernel=rbf;, score=0.946 total time= 1.8min
# [CV 4/5; 7/25] START C=1000, gamma=0.001, kernel=rbf............................
# [CV 4/5; 5/25] END C=0.1, gamma=0.001, kernel=rbf;, score=0.853 total time= 9.3min
# [CV 5/5; 7/25] START C=1000, gamma=0.001, kernel=rbf............................
# [CV 5/5; 5/25] END C=0.1, gamma=0.001, kernel=rbf;, score=0.858 total time= 9.3min
# [CV 1/5; 8/25] START C=100, gamma=0.0001, kernel=rbf............................
# [CV 4/5; 7/25] END C=1000, gamma=0.001, kernel=rbf;, score=0.940 total time= 1.9min
# [CV 2/5; 8/25] START C=100, gamma=0.0001, kernel=rbf............................
# [CV 5/5; 7/25] END C=1000, gamma=0.001, kernel=rbf;, score=0.935 total time= 1.7min
# [CV 3/5; 8/25] START C=100, gamma=0.0001, kernel=rbf............................
# [CV 1/5; 8/25] END C=100, gamma=0.0001, kernel=rbf;, score=0.929 total time= 2.1min
# [CV 4/5; 8/25] START C=100, gamma=0.0001, kernel=rbf............................
# [CV 2/5; 8/25] END C=100, gamma=0.0001, kernel=rbf;, score=0.935 total time= 2.0min
# [CV 5/5; 8/25] START C=100, gamma=0.0001, kernel=rbf............................
# [CV 3/5; 8/25] END C=100, gamma=0.0001, kernel=rbf;, score=0.933 total time= 1.9min
# [CV 1/5; 9/25] START C=1, gamma=0.01, kernel=rbf................................
# [CV 4/5; 8/25] END C=100, gamma=0.0001, kernel=rbf;, score=0.929 total time= 1.8min
# [CV 2/5; 9/25] START C=1, gamma=0.01, kernel=rbf................................
# [CV 5/5; 8/25] END C=100, gamma=0.0001, kernel=rbf;, score=0.924 total time= 1.9min
# [CV 3/5; 9/25] START C=1, gamma=0.01, kernel=rbf................................
# [CV 1/5; 9/25] END .C=1, gamma=0.01, kernel=rbf;, score=0.955 total time= 2.5min
# [CV 4/5; 9/25] START C=1, gamma=0.01, kernel=rbf................................
# [CV 2/5; 9/25] END .C=1, gamma=0.01, kernel=rbf;, score=0.962 total time= 2.6min
# [CV 5/5; 9/25] START C=1, gamma=0.01, kernel=rbf................................
# [CV 3/5; 9/25] END .C=1, gamma=0.01, kernel=rbf;, score=0.958 total time= 2.4min
# [CV 1/5; 10/25] START C=0.1, kernel=linear......................................
# [CV 1/5; 6/25] END C=0.1, gamma=0.0001, kernel=rbf;, score=0.204 total time=15.7min
# [CV 2/5; 10/25] START C=0.1, kernel=linear......................................
# [CV 2/5; 6/25] END C=0.1, gamma=0.0001, kernel=rbf;, score=0.199 total time=15.3min
# [CV 3/5; 10/25] START C=0.1, kernel=linear......................................
# [CV 3/5; 6/25] END C=0.1, gamma=0.0001, kernel=rbf;, score=0.202 total time=15.2min
# [CV 4/5; 10/25] START C=0.1, kernel=linear......................................
# [CV 4/5; 6/25] END C=0.1, gamma=0.0001, kernel=rbf;, score=0.199 total time=15.1min
# [CV 5/5; 10/25] START C=0.1, kernel=linear......................................
# [CV 4/5; 9/25] END .C=1, gamma=0.01, kernel=rbf;, score=0.953 total time= 2.1min
# [CV 1/5; 11/25] START C=1000, kernel=linear.....................................
# [CV 1/5; 10/25] END .......C=0.1, kernel=linear;, score=0.928 total time= 1.3min
# [CV 2/5; 11/25] START C=1000, kernel=linear.....................................
# [CV 2/5; 10/25] END .......C=0.1, kernel=linear;, score=0.933 total time= 1.3min
# [CV 3/5; 11/25] START C=1000, kernel=linear.....................................
# [CV 5/5; 6/25] END C=0.1, gamma=0.0001, kernel=rbf;, score=0.196 total time=15.6min
# [CV 4/5; 11/25] START C=1000, kernel=linear.....................................
# [CV 3/5; 10/25] END .......C=0.1, kernel=linear;, score=0.932 total time= 1.3min
# [CV 5/5; 11/25] START C=1000, kernel=linear.....................................
# [CV 5/5; 9/25] END .C=1, gamma=0.01, kernel=rbf;, score=0.958 total time= 2.1min
# [CV 1/5; 12/25] START C=10, gamma=0.1, kernel=rbf...............................
# [CV 4/5; 10/25] END .......C=0.1, kernel=linear;, score=0.927 total time= 1.3min
# [CV 2/5; 12/25] START C=10, gamma=0.1, kernel=rbf...............................
# [CV 5/5; 10/25] END .......C=0.1, kernel=linear;, score=0.922 total time= 1.3min
# [CV 3/5; 12/25] START C=10, gamma=0.1, kernel=rbf...............................
# [CV 1/5; 11/25] END ......C=1000, kernel=linear;, score=0.904 total time= 1.4min
# [CV 4/5; 12/25] START C=10, gamma=0.1, kernel=rbf...............................
# [CV 2/5; 11/25] END ......C=1000, kernel=linear;, score=0.916 total time= 1.4min
# [CV 5/5; 12/25] START C=10, gamma=0.1, kernel=rbf...............................
# [CV 3/5; 11/25] END ......C=1000, kernel=linear;, score=0.911 total time= 1.5min
# [CV 1/5; 13/25] START C=0.1, gamma=1, kernel=rbf................................
# [CV 4/5; 11/25] END ......C=1000, kernel=linear;, score=0.903 total time= 1.4min
# [CV 2/5; 13/25] START C=0.1, gamma=1, kernel=rbf................................
# [CV 5/5; 11/25] END ......C=1000, kernel=linear;, score=0.896 total time= 1.5min
# [CV 3/5; 13/25] START C=0.1, gamma=1, kernel=rbf................................
# [CV 1/5; 12/25] END C=10, gamma=0.1, kernel=rbf;, score=0.892 total time=14.9min
# [CV 4/5; 13/25] START C=0.1, gamma=1, kernel=rbf................................
# [CV 3/5; 12/25] END C=10, gamma=0.1, kernel=rbf;, score=0.886 total time=15.0min
# [CV 5/5; 13/25] START C=0.1, gamma=1, kernel=rbf................................
# [CV 2/5; 12/25] END C=10, gamma=0.1, kernel=rbf;, score=0.905 total time=15.4min
# [CV 1/5; 14/25] START C=1, gamma=0.001, kernel=rbf..............................
# [CV 4/5; 12/25] END C=10, gamma=0.1, kernel=rbf;, score=0.901 total time=15.0min
# [CV 2/5; 14/25] START C=1, gamma=0.001, kernel=rbf..............................
# [CV 5/5; 12/25] END C=10, gamma=0.1, kernel=rbf;, score=0.893 total time=15.0min
# [CV 3/5; 14/25] START C=1, gamma=0.001, kernel=rbf..............................
# [CV 2/5; 13/25] END .C=0.1, gamma=1, kernel=rbf;, score=0.112 total time=16.2min
# [CV 4/5; 14/25] START C=1, gamma=0.001, kernel=rbf..............................
# [CV 1/5; 13/25] END .C=0.1, gamma=1, kernel=rbf;, score=0.112 total time=16.7min
# [CV 5/5; 14/25] START C=1, gamma=0.001, kernel=rbf..............................
# [CV 3/5; 13/25] END .C=0.1, gamma=1, kernel=rbf;, score=0.112 total time=16.5min
# [CV 1/5; 15/25] START C=1, gamma=0.1, kernel=rbf................................
# [CV 2/5; 14/25] END C=1, gamma=0.001, kernel=rbf;, score=0.922 total time= 4.0min
# [CV 2/5; 15/25] START C=1, gamma=0.1, kernel=rbf................................
# [CV 1/5; 14/25] END C=1, gamma=0.001, kernel=rbf;, score=0.916 total time= 4.1min
# [CV 3/5; 15/25] START C=1, gamma=0.1, kernel=rbf................................
# [CV 3/5; 14/25] END C=1, gamma=0.001, kernel=rbf;, score=0.915 total time= 3.9min
# [CV 4/5; 15/25] START C=1, gamma=0.1, kernel=rbf................................
# [CV 4/5; 14/25] END C=1, gamma=0.001, kernel=rbf;, score=0.915 total time= 4.4min
# [CV 5/5; 15/25] START C=1, gamma=0.1, kernel=rbf................................
# [CV 5/5; 14/25] END C=1, gamma=0.001, kernel=rbf;, score=0.912 total time= 4.4min
# [CV 1/5; 16/25] START C=100, gamma=0.01, kernel=rbf.............................
# [CV 1/5; 16/25] END C=100, gamma=0.01, kernel=rbf;, score=0.962 total time= 2.4min
# [CV 2/5; 16/25] START C=100, gamma=0.01, kernel=rbf.............................
# [CV 2/5; 16/25] END C=100, gamma=0.01, kernel=rbf;, score=0.971 total time= 2.3min
# [CV 3/5; 16/25] START C=100, gamma=0.01, kernel=rbf.............................
# [CV 3/5; 16/25] END C=100, gamma=0.01, kernel=rbf;, score=0.964 total time= 2.4min
# [CV 4/5; 16/25] START C=100, gamma=0.01, kernel=rbf.............................
# [CV 4/5; 13/25] END .C=0.1, gamma=1, kernel=rbf;, score=0.112 total time=16.4min
# [CV 5/5; 16/25] START C=100, gamma=0.01, kernel=rbf.............................
# [CV 4/5; 16/25] END C=100, gamma=0.01, kernel=rbf;, score=0.964 total time= 2.1min
# [CV 1/5; 17/25] START C=1, kernel=linear........................................
# [CV 5/5; 13/25] END .C=0.1, gamma=1, kernel=rbf;, score=0.112 total time=16.6min
# [CV 2/5; 17/25] START C=1, kernel=linear........................................
# [CV 1/5; 17/25] END .........C=1, kernel=linear;, score=0.913 total time= 1.5min
# [CV 3/5; 17/25] START C=1, kernel=linear........................................
# [CV 1/5; 15/25] END .C=1, gamma=0.1, kernel=rbf;, score=0.885 total time=15.3min
# [CV 4/5; 17/25] START C=1, kernel=linear........................................
# [CV 5/5; 16/25] END C=100, gamma=0.01, kernel=rbf;, score=0.964 total time= 2.2min
# [CV 5/5; 17/25] START C=1, kernel=linear........................................
# [CV 2/5; 17/25] END .........C=1, kernel=linear;, score=0.920 total time= 1.5min
# [CV 1/5; 18/25] START C=10, kernel=linear.......................................
# [CV 3/5; 17/25] END .........C=1, kernel=linear;, score=0.916 total time= 1.4min
# [CV 2/5; 18/25] START C=10, kernel=linear.......................................
# [CV 4/5; 17/25] END .........C=1, kernel=linear;, score=0.909 total time= 1.3min
# [CV 3/5; 18/25] START C=10, kernel=linear.......................................
# [CV 2/5; 15/25] END .C=1, gamma=0.1, kernel=rbf;, score=0.901 total time=14.8min
# [CV 4/5; 18/25] START C=10, kernel=linear.......................................
# [CV 4/5; 15/25] END .C=1, gamma=0.1, kernel=rbf;, score=0.896 total time=14.9min
# [CV 5/5; 18/25] START C=10, kernel=linear.......................................
# [CV 5/5; 17/25] END .........C=1, kernel=linear;, score=0.906 total time= 1.3min
# [CV 1/5; 19/25] START C=1000, gamma=1, kernel=rbf...............................
# [CV 1/5; 18/25] END ........C=10, kernel=linear;, score=0.904 total time= 1.3min
# [CV 2/5; 19/25] START C=1000, gamma=1, kernel=rbf...............................
# [CV 3/5; 15/25] END .C=1, gamma=0.1, kernel=rbf;, score=0.882 total time=15.5min
# [CV 3/5; 19/25] START C=1000, gamma=1, kernel=rbf...............................
# [CV 2/5; 18/25] END ........C=10, kernel=linear;, score=0.916 total time= 1.5min
# [CV 4/5; 19/25] START C=1000, gamma=1, kernel=rbf...............................
# [CV 3/5; 18/25] END ........C=10, kernel=linear;, score=0.911 total time= 1.5min
# [CV 5/5; 19/25] START C=1000, gamma=1, kernel=rbf...............................
# [CV 4/5; 18/25] END ........C=10, kernel=linear;, score=0.903 total time= 1.4min
# [CV 1/5; 20/25] START C=100, kernel=linear......................................
# [CV 5/5; 18/25] END ........C=10, kernel=linear;, score=0.896 total time= 1.4min
# [CV 2/5; 20/25] START C=100, kernel=linear......................................
# [CV 5/5; 15/25] END .C=1, gamma=0.1, kernel=rbf;, score=0.884 total time=14.7min
# [CV 3/5; 20/25] START C=100, kernel=linear......................................
# [CV 1/5; 20/25] END .......C=100, kernel=linear;, score=0.904 total time= 1.4min
# [CV 4/5; 20/25] START C=100, kernel=linear......................................
# [CV 2/5; 20/25] END .......C=100, kernel=linear;, score=0.916 total time= 1.4min
# [CV 5/5; 20/25] START C=100, kernel=linear......................................
# [CV 3/5; 20/25] END .......C=100, kernel=linear;, score=0.911 total time= 1.4min
# [CV 1/5; 21/25] START C=100, gamma=0.1, kernel=rbf..............................
# [CV 4/5; 20/25] END .......C=100, kernel=linear;, score=0.903 total time= 1.4min
# [CV 2/5; 21/25] START C=100, gamma=0.1, kernel=rbf..............................
# [CV 5/5; 20/25] END .......C=100, kernel=linear;, score=0.896 total time= 1.5min
# [CV 3/5; 21/25] START C=100, gamma=0.1, kernel=rbf..............................
# [CV 1/5; 19/25] END C=1000, gamma=1, kernel=rbf;, score=0.179 total time=15.3min
# [CV 4/5; 21/25] START C=100, gamma=0.1, kernel=rbf..............................
# [CV 2/5; 19/25] END C=1000, gamma=1, kernel=rbf;, score=0.181 total time=15.2min
# [CV 5/5; 21/25] START C=100, gamma=0.1, kernel=rbf..............................
# [CV 3/5; 19/25] END C=1000, gamma=1, kernel=rbf;, score=0.180 total time=15.6min
# [CV 1/5; 22/25] START C=1000, gamma=0.1, kernel=rbf.............................
# [CV 5/5; 19/25] END C=1000, gamma=1, kernel=rbf;, score=0.178 total time=15.2min
# [CV 2/5; 22/25] START C=1000, gamma=0.1, kernel=rbf.............................
# [CV 4/5; 19/25] END C=1000, gamma=1, kernel=rbf;, score=0.181 total time=15.5min
# [CV 3/5; 22/25] START C=1000, gamma=0.1, kernel=rbf.............................
# [CV 1/5; 21/25] END C=100, gamma=0.1, kernel=rbf;, score=0.892 total time=13.9min
# [CV 4/5; 22/25] START C=1000, gamma=0.1, kernel=rbf.............................
# [CV 2/5; 21/25] END C=100, gamma=0.1, kernel=rbf;, score=0.905 total time=13.3min
# [CV 5/5; 22/25] START C=1000, gamma=0.1, kernel=rbf.............................
# [CV 3/5; 21/25] END C=100, gamma=0.1, kernel=rbf;, score=0.886 total time=13.4min
# [CV 1/5; 23/25] START C=10, gamma=0.001, kernel=rbf.............................
# [CV 1/5; 23/25] END C=10, gamma=0.001, kernel=rbf;, score=0.935 total time= 1.9min
# [CV 2/5; 23/25] START C=10, gamma=0.001, kernel=rbf.............................
# [CV 2/5; 23/25] END C=10, gamma=0.001, kernel=rbf;, score=0.942 total time= 1.9min
# [CV 3/5; 23/25] START C=10, gamma=0.001, kernel=rbf.............................
# [CV 3/5; 23/25] END C=10, gamma=0.001, kernel=rbf;, score=0.938 total time= 1.8min
# [CV 4/5; 23/25] START C=10, gamma=0.001, kernel=rbf.............................
# [CV 4/5; 23/25] END C=10, gamma=0.001, kernel=rbf;, score=0.934 total time= 1.7min
# [CV 5/5; 23/25] START C=10, gamma=0.001, kernel=rbf.............................
# [CV 5/5; 23/25] END C=10, gamma=0.001, kernel=rbf;, score=0.931 total time= 1.7min
# [CV 1/5; 24/25] START C=1000, gamma=0.0001, kernel=rbf..........................
# [CV 4/5; 21/25] END C=100, gamma=0.1, kernel=rbf;, score=0.901 total time=12.7min
# [CV 2/5; 24/25] START C=1000, gamma=0.0001, kernel=rbf..........................
# [CV 1/5; 24/25] END C=1000, gamma=0.0001, kernel=rbf;, score=0.930 total time= 1.3min
# [CV 3/5; 24/25] START C=1000, gamma=0.0001, kernel=rbf..........................
# [CV 5/5; 21/25] END C=100, gamma=0.1, kernel=rbf;, score=0.893 total time=12.7min
# [CV 4/5; 24/25] START C=1000, gamma=0.0001, kernel=rbf..........................
# [CV 1/5; 22/25] END C=1000, gamma=0.1, kernel=rbf;, score=0.892 total time=12.7min
# [CV 5/5; 24/25] START C=1000, gamma=0.0001, kernel=rbf..........................
# [CV 2/5; 22/25] END C=1000, gamma=0.1, kernel=rbf;, score=0.905 total time=12.9min
# [CV 1/5; 25/25] START C=100, gamma=1, kernel=rbf................................
# [CV 2/5; 24/25] END C=1000, gamma=0.0001, kernel=rbf;, score=0.932 total time= 1.4min
# [CV 2/5; 25/25] START C=100, gamma=1, kernel=rbf................................
# [CV 3/5; 24/25] END C=1000, gamma=0.0001, kernel=rbf;, score=0.931 total time= 1.4min
# [CV 3/5; 25/25] START C=100, gamma=1, kernel=rbf................................
# [CV 3/5; 22/25] END C=1000, gamma=0.1, kernel=rbf;, score=0.886 total time=13.0min
# [CV 4/5; 25/25] START C=100, gamma=1, kernel=rbf................................
# [CV 4/5; 24/25] END C=1000, gamma=0.0001, kernel=rbf;, score=0.929 total time= 1.3min
# [CV 5/5; 25/25] START C=100, gamma=1, kernel=rbf................................
# [CV 4/5; 22/25] END C=1000, gamma=0.1, kernel=rbf;, score=0.901 total time=12.6min
# [CV 5/5; 22/25] END C=1000, gamma=0.1, kernel=rbf;, score=0.893 total time=12.6min
# [CV 5/5; 24/25] END C=1000, gamma=0.0001, kernel=rbf;, score=0.921 total time= 1.3min
# [CV 3/5; 25/25] END .C=100, gamma=1, kernel=rbf;, score=0.180 total time= 8.9min
# [CV 2/5; 25/25] END .C=100, gamma=1, kernel=rbf;, score=0.181 total time= 8.9min
# [CV 5/5; 25/25] END .C=100, gamma=1, kernel=rbf;, score=0.178 total time= 8.8min
# [CV 1/5; 25/25] END .C=100, gamma=1, kernel=rbf;, score=0.179 total time= 9.2min
# [CV 4/5; 25/25] END .C=100, gamma=1, kernel=rbf;, score=0.181 total time= 9.0min
# The best parameter is {'kernel': 'rbf', 'gamma': 0.01, 'C': 10}
# The best score is 0.9658
# The best estimator SVC(C=10, gamma=0.01, random_state=42)

# %%
df_results = df = pd.read_csv("random_search_results.csv")
df_sorted = df.sort_values(by="mean_test_score", ascending=True)
df_sorted = df_sorted[['param_C', 'param_kernel', 'param_gamma', 'mean_test_score']]
df_sorted
# Out:
#     param_C param_kernel  param_gamma  mean_test_score
# 12      0.1          rbf       1.0000         0.112333
# 18   1000.0          rbf       1.0000         0.179867
# 24    100.0          rbf       1.0000         0.179867
# 1      10.0          rbf       1.0000         0.179867
# 5       0.1          rbf       0.0001         0.200000
# 4       0.1          rbf       0.0010         0.855533
# 14      1.0          rbf       0.1000         0.889667
# 21   1000.0          rbf       0.1000         0.895467
# 11     10.0          rbf       0.1000         0.895467
# 20    100.0          rbf       0.1000         0.895467
# 19    100.0       linear          NaN         0.905933
# 17     10.0       linear          NaN         0.905933
# 10   1000.0       linear          NaN         0.905933
# 16      1.0       linear          NaN         0.913000
# 13      1.0          rbf       0.0010         0.916000
# 9       0.1       linear          NaN         0.928267
# 23   1000.0          rbf       0.0001         0.928333
# 7     100.0          rbf       0.0001         0.929933
# 22     10.0          rbf       0.0010         0.935933
# 6    1000.0          rbf       0.0010         0.941200
# 2     100.0          rbf       0.0010         0.944000
# 8       1.0          rbf       0.0100         0.957067
# 0    1000.0          rbf       0.0100         0.965000
# 15    100.0          rbf       0.0100         0.965000
# 3      10.0          rbf       0.0100         0.965800

# %%
X_sub, _, y_sub, _ = train_test_split(
    X_train, y_train,
    train_size=15000,
    stratify=y_train,
    random_state=43
)

# %%
# new subclasses without gamma = 1 due to bad results
C_range = [0.1, 1, 10, 100, 1000] 
gamma_range = [0.1, 0.01, 0.001, 0.0001] 
kernels = ['linear', 'rbf'] 
param_dist = [ 
    {'kernel': ['linear'], 'C': C_range}, 
    {'kernel': ['rbf'], 'C': C_range, 'gamma': gamma_range} 
    ]

random_search = RandomizedSearchCV(SVC(random_state=42), param_dist, n_iter=20, refit=True, cv=5, verbose=10, n_jobs=-1, random_state=42, return_train_score=True)
random_search.fit(X_sub,y_sub)

results = random_search.cv_results_
df_results = pd.DataFrame(results)
df_results.to_csv("random_search_results20.csv", index=False)
print(f'The best parameter is {random_search.best_params_}')
print(f'The best score is {random_search.best_score_}')
print(f'The best estimator {random_search.best_estimator_}')
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5; 2/20] START C=10, gamma=0.0001, kernel=rbf.............................
# [CV 5/5; 1/20] START C=0.1, gamma=0.0001, kernel=rbf............................
# [CV 2/5; 1/20] START C=0.1, gamma=0.0001, kernel=rbf............................
# [CV 4/5; 1/20] START C=0.1, gamma=0.0001, kernel=rbf............................
# [CV 3/5; 1/20] START C=0.1, gamma=0.0001, kernel=rbf............................
# [CV 1/5; 1/20] START C=0.1, gamma=0.0001, kernel=rbf............................
# [CV 2/5; 2/20] START C=10, gamma=0.0001, kernel=rbf.............................
# [CV 3/5; 2/20] START C=10, gamma=0.0001, kernel=rbf.............................
# [CV 1/5; 2/20] END C=10, gamma=0.0001, kernel=rbf;, score=(train=0.919, test=0.912) total time= 3.8min
# [CV 4/5; 2/20] START C=10, gamma=0.0001, kernel=rbf.............................
# [CV 3/5; 2/20] END C=10, gamma=0.0001, kernel=rbf;, score=(train=0.918, test=0.909) total time= 3.9min
# [CV 5/5; 2/20] START C=10, gamma=0.0001, kernel=rbf.............................
# [CV 2/5; 2/20] END C=10, gamma=0.0001, kernel=rbf;, score=(train=0.917, test=0.915) total time= 3.9min
# [CV 1/5; 3/20] START C=0.1, kernel=linear.......................................
# [CV 1/5; 3/20] END C=0.1, kernel=linear;, score=(train=0.970, test=0.929) total time= 1.5min
# [CV 2/5; 3/20] START C=0.1, kernel=linear.......................................
# [CV 2/5; 3/20] END C=0.1, kernel=linear;, score=(train=0.971, test=0.929) total time= 1.5min
# [CV 3/5; 3/20] START C=0.1, kernel=linear.......................................
# [CV 3/5; 3/20] END C=0.1, kernel=linear;, score=(train=0.970, test=0.929) total time= 1.2min
# [CV 4/5; 3/20] START C=0.1, kernel=linear.......................................
# [CV 4/5; 2/20] END C=10, gamma=0.0001, kernel=rbf;, score=(train=0.916, test=0.916) total time= 4.2min
# [CV 5/5; 3/20] START C=0.1, kernel=linear.......................................
# [CV 5/5; 2/20] END C=10, gamma=0.0001, kernel=rbf;, score=(train=0.919, test=0.906) total time= 4.2min
# [CV 1/5; 4/20] START C=1000, gamma=0.001, kernel=rbf............................
# [CV 4/5; 3/20] END C=0.1, kernel=linear;, score=(train=0.968, test=0.934) total time= 1.2min
# [CV 2/5; 4/20] START C=1000, gamma=0.001, kernel=rbf............................
# [CV 5/5; 3/20] END C=0.1, kernel=linear;, score=(train=0.969, test=0.927) total time= 1.2min
# [CV 3/5; 4/20] START C=1000, gamma=0.001, kernel=rbf............................
# [CV 1/5; 4/20] END C=1000, gamma=0.001, kernel=rbf;, score=(train=1.000, test=0.944) total time= 1.4min
# [CV 4/5; 4/20] START C=1000, gamma=0.001, kernel=rbf............................
# [CV 2/5; 4/20] END C=1000, gamma=0.001, kernel=rbf;, score=(train=1.000, test=0.943) total time= 1.5min
# [CV 5/5; 4/20] START C=1000, gamma=0.001, kernel=rbf............................
# [CV 3/5; 4/20] END C=1000, gamma=0.001, kernel=rbf;, score=(train=1.000, test=0.946) total time= 1.4min
# [CV 1/5; 5/20] START C=1, gamma=0.001, kernel=rbf...............................
# [CV 5/5; 1/20] END C=0.1, gamma=0.0001, kernel=rbf;, score=(train=0.202, test=0.202) total time=15.0min
# [CV 2/5; 5/20] START C=1, gamma=0.001, kernel=rbf...............................
# [CV 1/5; 1/20] END C=0.1, gamma=0.0001, kernel=rbf;, score=(train=0.203, test=0.196) total time=15.0min
# [CV 3/5; 1/20] END C=0.1, gamma=0.0001, kernel=rbf;, score=(train=0.200, test=0.199) total time=15.1min
# [CV 3/5; 5/20] START C=1, gamma=0.001, kernel=rbf...............................
# [CV 4/5; 5/20] START C=1, gamma=0.001, kernel=rbf...............................
# [CV 4/5; 1/20] END C=0.1, gamma=0.0001, kernel=rbf;, score=(train=0.200, test=0.206) total time=15.2min
# [CV 5/5; 5/20] START C=1, gamma=0.001, kernel=rbf...............................
# [CV 4/5; 4/20] END C=1000, gamma=0.001, kernel=rbf;, score=(train=1.000, test=0.947) total time= 1.5min
# [CV 1/5; 6/20] START C=1, gamma=0.1, kernel=rbf.................................
# [CV 2/5; 1/20] END C=0.1, gamma=0.0001, kernel=rbf;, score=(train=0.199, test=0.198) total time=15.4min
# [CV 2/5; 6/20] START C=1, gamma=0.1, kernel=rbf.................................
# [CV 5/5; 4/20] END C=1000, gamma=0.001, kernel=rbf;, score=(train=1.000, test=0.944) total time= 1.5min
# [CV 3/5; 6/20] START C=1, gamma=0.1, kernel=rbf.................................
# [CV 1/5; 5/20] END C=1, gamma=0.001, kernel=rbf;, score=(train=0.923, test=0.914) total time= 3.8min
# [CV 4/5; 6/20] START C=1, gamma=0.1, kernel=rbf.................................
# [CV 2/5; 5/20] END C=1, gamma=0.001, kernel=rbf;, score=(train=0.919, test=0.919) total time= 4.0min
# [CV 5/5; 6/20] START C=1, gamma=0.1, kernel=rbf.................................
# [CV 3/5; 5/20] END C=1, gamma=0.001, kernel=rbf;, score=(train=0.921, test=0.912) total time= 3.9min
# [CV 1/5; 7/20] START C=10, gamma=0.1, kernel=rbf................................
# [CV 4/5; 5/20] END C=1, gamma=0.001, kernel=rbf;, score=(train=0.918, test=0.920) total time= 3.9min
# [CV 2/5; 7/20] START C=10, gamma=0.1, kernel=rbf................................
# [CV 5/5; 5/20] END C=1, gamma=0.001, kernel=rbf;, score=(train=0.921, test=0.908) total time= 3.9min
# [CV 3/5; 7/20] START C=10, gamma=0.1, kernel=rbf................................
# [CV 1/5; 6/20] END C=1, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.890) total time=13.7min
# [CV 4/5; 7/20] START C=10, gamma=0.1, kernel=rbf................................
# [CV 2/5; 6/20] END C=1, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.890) total time=13.6min
# [CV 5/5; 7/20] START C=10, gamma=0.1, kernel=rbf................................
# [CV 3/5; 6/20] END C=1, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.887) total time=13.7min
# [CV 1/5; 8/20] START C=1, kernel=linear.........................................
# [CV 1/5; 8/20] END C=1, kernel=linear;, score=(train=0.994, test=0.917) total time= 1.1min
# [CV 2/5; 8/20] START C=1, kernel=linear.........................................
# [CV 4/5; 6/20] END C=1, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.885) total time=13.6min
# [CV 3/5; 8/20] START C=1, kernel=linear.........................................
# [CV 1/5; 7/20] END C=10, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.898) total time=13.6min
# [CV 4/5; 8/20] START C=1, kernel=linear.........................................
# [CV 5/5; 6/20] END C=1, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.877) total time=13.7min
# [CV 5/5; 8/20] START C=1, kernel=linear.........................................
# [CV 2/5; 8/20] END C=1, kernel=linear;, score=(train=0.995, test=0.913) total time= 1.1min
# [CV 1/5; 9/20] START C=1000, gamma=0.01, kernel=rbf.............................
# [CV 2/5; 7/20] END C=10, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.896) total time=13.8min
# [CV 2/5; 9/20] START C=1000, gamma=0.01, kernel=rbf.............................
# [CV 3/5; 7/20] END C=10, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.892) total time=13.9min
# [CV 3/5; 9/20] START C=1000, gamma=0.01, kernel=rbf.............................
# [CV 3/5; 8/20] END C=1, kernel=linear;, score=(train=0.994, test=0.916) total time= 1.1min
# [CV 4/5; 9/20] START C=1000, gamma=0.01, kernel=rbf.............................
# [CV 5/5; 8/20] END C=1, kernel=linear;, score=(train=0.994, test=0.918) total time= 1.2min
# [CV 5/5; 9/20] START C=1000, gamma=0.01, kernel=rbf.............................
# [CV 4/5; 8/20] END C=1, kernel=linear;, score=(train=0.994, test=0.918) total time= 1.2min
# [CV 1/5; 10/20] START C=0.1, gamma=0.1, kernel=rbf..............................
# [CV 1/5; 9/20] END C=1000, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.968) total time= 1.9min
# [CV 2/5; 10/20] START C=0.1, gamma=0.1, kernel=rbf..............................
# [CV 2/5; 9/20] END C=1000, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.965) total time= 1.8min
# [CV 3/5; 10/20] START C=0.1, gamma=0.1, kernel=rbf..............................
# [CV 3/5; 9/20] END C=1000, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.968) total time= 1.8min
# [CV 4/5; 10/20] START C=0.1, gamma=0.1, kernel=rbf..............................
# [CV 4/5; 9/20] END C=1000, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.971) total time= 1.8min
# [CV 5/5; 10/20] START C=0.1, gamma=0.1, kernel=rbf..............................
# [CV 5/5; 9/20] END C=1000, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.971) total time= 1.7min
# [CV 1/5; 11/20] START C=10, kernel=linear.......................................
# [CV 1/5; 11/20] END C=10, kernel=linear;, score=(train=1.000, test=0.909) total time= 1.2min
# [CV 2/5; 11/20] START C=10, kernel=linear.......................................
# [CV 2/5; 11/20] END C=10, kernel=linear;, score=(train=1.000, test=0.903) total time= 1.2min
# [CV 3/5; 11/20] START C=10, kernel=linear.......................................
# [CV 4/5; 7/20] END C=10, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.891) total time=11.8min
# [CV 4/5; 11/20] START C=10, kernel=linear.......................................
# [CV 5/5; 7/20] END C=10, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.884) total time=12.1min
# [CV 5/5; 11/20] START C=10, kernel=linear.......................................
# [CV 3/5; 11/20] END C=10, kernel=linear;, score=(train=1.000, test=0.909) total time= 1.2min
# [CV 1/5; 12/20] START C=1, gamma=0.0001, kernel=rbf.............................
# [CV 4/5; 11/20] END C=10, kernel=linear;, score=(train=1.000, test=0.910) total time= 1.3min
# [CV 2/5; 12/20] START C=1, gamma=0.0001, kernel=rbf.............................
# [CV 5/5; 11/20] END C=10, kernel=linear;, score=(train=1.000, test=0.913) total time= 1.4min
# [CV 3/5; 12/20] START C=1, gamma=0.0001, kernel=rbf.............................
# [CV 1/5; 10/20] END C=0.1, gamma=0.1, kernel=rbf;, score=(train=0.347, test=0.316) total time=12.2min
# [CV 4/5; 12/20] START C=1, gamma=0.0001, kernel=rbf.............................
# [CV 2/5; 10/20] END C=0.1, gamma=0.1, kernel=rbf;, score=(train=0.341, test=0.309) total time=12.6min
# [CV 5/5; 12/20] START C=1, gamma=0.0001, kernel=rbf.............................
# [CV 3/5; 10/20] END C=0.1, gamma=0.1, kernel=rbf;, score=(train=0.337, test=0.312) total time=12.5min
# [CV 1/5; 13/20] START C=10, gamma=0.001, kernel=rbf.............................
# [CV 4/5; 10/20] END C=0.1, gamma=0.1, kernel=rbf;, score=(train=0.344, test=0.310) total time=12.7min
# [CV 2/5; 13/20] START C=10, gamma=0.001, kernel=rbf.............................
# [CV 5/5; 10/20] END C=0.1, gamma=0.1, kernel=rbf;, score=(train=0.332, test=0.305) total time=12.9min
# [CV 3/5; 13/20] START C=10, gamma=0.001, kernel=rbf.............................
# [CV 1/5; 12/20] END C=1, gamma=0.0001, kernel=rbf;, score=(train=0.858, test=0.855) total time= 8.9min
# [CV 4/5; 13/20] START C=10, gamma=0.001, kernel=rbf.............................
# [CV 1/5; 13/20] END C=10, gamma=0.001, kernel=rbf;, score=(train=0.958, test=0.935) total time= 1.7min
# [CV 5/5; 13/20] START C=10, gamma=0.001, kernel=rbf.............................
# [CV 2/5; 13/20] END C=10, gamma=0.001, kernel=rbf;, score=(train=0.957, test=0.935) total time= 1.8min
# [CV 1/5; 14/20] START C=100, kernel=linear......................................
# [CV 2/5; 12/20] END C=1, gamma=0.0001, kernel=rbf;, score=(train=0.858, test=0.855) total time= 8.8min
# [CV 2/5; 14/20] START C=100, kernel=linear......................................
# [CV 3/5; 12/20] END C=1, gamma=0.0001, kernel=rbf;, score=(train=0.860, test=0.853) total time= 8.8min
# [CV 3/5; 14/20] START C=100, kernel=linear......................................
# [CV 3/5; 13/20] END C=10, gamma=0.001, kernel=rbf;, score=(train=0.957, test=0.934) total time= 1.8min
# [CV 4/5; 14/20] START C=100, kernel=linear......................................
# [CV 1/5; 14/20] END C=100, kernel=linear;, score=(train=1.000, test=0.908) total time= 1.3min
# [CV 5/5; 14/20] START C=100, kernel=linear......................................
# [CV 2/5; 14/20] END C=100, kernel=linear;, score=(train=1.000, test=0.902) total time= 1.3min
# [CV 1/5; 15/20] START C=1000, kernel=linear.....................................
# [CV 3/5; 14/20] END C=100, kernel=linear;, score=(train=1.000, test=0.907) total time= 1.3min
# [CV 2/5; 15/20] START C=1000, kernel=linear.....................................
# [CV 4/5; 14/20] END C=100, kernel=linear;, score=(train=1.000, test=0.908) total time= 1.3min
# [CV 3/5; 15/20] START C=1000, kernel=linear.....................................
# [CV 4/5; 13/20] END C=10, gamma=0.001, kernel=rbf;, score=(train=0.955, test=0.941) total time= 1.8min
# [CV 4/5; 15/20] START C=1000, kernel=linear.....................................
# [CV 5/5; 13/20] END C=10, gamma=0.001, kernel=rbf;, score=(train=0.957, test=0.937) total time= 1.7min
# [CV 5/5; 15/20] START C=1000, kernel=linear.....................................
# [CV 5/5; 14/20] END C=100, kernel=linear;, score=(train=1.000, test=0.913) total time= 1.4min
# [CV 1/5; 16/20] START C=100, gamma=0.0001, kernel=rbf...........................
# [CV 1/5; 15/20] END C=1000, kernel=linear;, score=(train=1.000, test=0.908) total time= 1.4min
# [CV 2/5; 16/20] START C=100, gamma=0.0001, kernel=rbf...........................
# [CV 2/5; 15/20] END C=1000, kernel=linear;, score=(train=1.000, test=0.902) total time= 1.4min
# [CV 3/5; 16/20] START C=100, gamma=0.0001, kernel=rbf...........................
# [CV 3/5; 15/20] END C=1000, kernel=linear;, score=(train=1.000, test=0.907) total time= 1.3min
# [CV 4/5; 16/20] START C=100, gamma=0.0001, kernel=rbf...........................
# [CV 4/5; 15/20] END C=1000, kernel=linear;, score=(train=1.000, test=0.908) total time= 1.3min
# [CV 5/5; 16/20] START C=100, gamma=0.0001, kernel=rbf...........................
# [CV 5/5; 15/20] END C=1000, kernel=linear;, score=(train=1.000, test=0.913) total time= 1.4min
# [CV 1/5; 17/20] START C=100, gamma=0.1, kernel=rbf..............................
# [CV 4/5; 12/20] END C=1, gamma=0.0001, kernel=rbf;, score=(train=0.858, test=0.863) total time= 8.0min
# [CV 2/5; 17/20] START C=100, gamma=0.1, kernel=rbf..............................
# [CV 1/5; 16/20] END C=100, gamma=0.0001, kernel=rbf;, score=(train=0.949, test=0.927) total time= 1.9min
# [CV 3/5; 17/20] START C=100, gamma=0.1, kernel=rbf..............................
# [CV 2/5; 16/20] END C=100, gamma=0.0001, kernel=rbf;, score=(train=0.950, test=0.929) total time= 1.8min
# [CV 4/5; 17/20] START C=100, gamma=0.1, kernel=rbf..............................
# [CV 3/5; 16/20] END C=100, gamma=0.0001, kernel=rbf;, score=(train=0.950, test=0.928) total time= 1.9min
# [CV 5/5; 17/20] START C=100, gamma=0.1, kernel=rbf..............................
# [CV 4/5; 16/20] END C=100, gamma=0.0001, kernel=rbf;, score=(train=0.949, test=0.937) total time= 1.8min
# [CV 1/5; 18/20] START C=1000, gamma=0.1, kernel=rbf.............................
# [CV 5/5; 12/20] END C=1, gamma=0.0001, kernel=rbf;, score=(train=0.858, test=0.850) total time= 8.2min
# [CV 2/5; 18/20] START C=1000, gamma=0.1, kernel=rbf.............................
# [CV 5/5; 16/20] END C=100, gamma=0.0001, kernel=rbf;, score=(train=0.949, test=0.927) total time= 1.8min
# [CV 3/5; 18/20] START C=1000, gamma=0.1, kernel=rbf.............................
# [CV 1/5; 17/20] END C=100, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.898) total time=13.5min
# [CV 4/5; 18/20] START C=1000, gamma=0.1, kernel=rbf.............................
# [CV 2/5; 17/20] END C=100, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.896) total time=13.8min
# [CV 5/5; 18/20] START C=1000, gamma=0.1, kernel=rbf.............................
# [CV 3/5; 17/20] END C=100, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.892) total time=14.1min
# [CV 1/5; 19/20] START C=100, gamma=0.01, kernel=rbf.............................
# [CV 4/5; 17/20] END C=100, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.891) total time=14.1min
# [CV 2/5; 19/20] START C=100, gamma=0.01, kernel=rbf.............................
# [CV 1/5; 18/20] END C=1000, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.898) total time=13.9min
# [CV 3/5; 19/20] START C=100, gamma=0.01, kernel=rbf.............................
# [CV 2/5; 18/20] END C=1000, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.896) total time=13.9min
# [CV 4/5; 19/20] START C=100, gamma=0.01, kernel=rbf.............................
# [CV 5/5; 17/20] END C=100, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.884) total time=14.5min
# [CV 5/5; 19/20] START C=100, gamma=0.01, kernel=rbf.............................
# [CV 3/5; 18/20] END C=1000, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.892) total time=14.0min
# [CV 1/5; 20/20] START C=1000, gamma=0.0001, kernel=rbf..........................
# [CV 1/5; 20/20] END C=1000, gamma=0.0001, kernel=rbf;, score=(train=0.981, test=0.930) total time= 1.9min
# [CV 2/5; 20/20] START C=1000, gamma=0.0001, kernel=rbf..........................
# [CV 1/5; 19/20] END C=100, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.968) total time= 2.5min
# [CV 3/5; 20/20] START C=1000, gamma=0.0001, kernel=rbf..........................
# [CV 2/5; 19/20] END C=100, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.965) total time= 2.4min
# [CV 4/5; 20/20] START C=1000, gamma=0.0001, kernel=rbf..........................
# [CV 3/5; 19/20] END C=100, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.968) total time= 2.6min
# [CV 5/5; 20/20] START C=1000, gamma=0.0001, kernel=rbf..........................
# [CV 4/5; 19/20] END C=100, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.971) total time= 2.5min
# [CV 5/5; 19/20] END C=100, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.971) total time= 2.5min
# [CV 2/5; 20/20] END C=1000, gamma=0.0001, kernel=rbf;, score=(train=0.981, test=0.926) total time= 1.4min
# [CV 3/5; 20/20] END C=1000, gamma=0.0001, kernel=rbf;, score=(train=0.981, test=0.928) total time= 1.3min
# [CV 4/5; 20/20] END C=1000, gamma=0.0001, kernel=rbf;, score=(train=0.981, test=0.935) total time= 1.3min
# [CV 5/5; 20/20] END C=1000, gamma=0.0001, kernel=rbf;, score=(train=0.981, test=0.929) total time= 1.1min
# [CV 4/5; 18/20] END C=1000, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.891) total time=11.9min
# [CV 5/5; 18/20] END C=1000, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.884) total time=10.8min
# The best parameter is {'kernel': 'rbf', 'gamma': 0.01, 'C': 1000}
# The best score is 0.9685333333333335
# The best estimator SVC(C=1000, gamma=0.01, random_state=42)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# ---- load results ----
df = pd.read_csv("results/random_search_results20.csv")
df.columns = df.columns.str.strip()

# ---- LINEAR: C vs. Accuracy ----
df_lin = df[df["param_kernel"] == "linear"].copy()
if not df_lin.empty:
    df_lin = df_lin.dropna(subset=["param_C"]).sort_values("param_C")

    plt.figure()
    plt.plot(df_lin["param_C"], df_lin["mean_test_score"], marker="o", label="Validation (CV mean)")
    if "mean_train_score" in df_lin.columns:
        plt.plot(df_lin["param_C"], df_lin["mean_train_score"], marker="o", label="Training (CV mean)")
    plt.xscale("log")
    plt.xlabel("C")
    plt.ylabel("Accuracy")
    plt.title("SVM Linear — Accuracy vs C")
    plt.legend()
    plt.tight_layout()
    plt.savefig("results/svm_linear_accuracy_vs_C.png", dpi=300)
    plt.close()  # Fenster schließen, spart Speicher

# ---- RBF: Heatmaps ----
df_rbf = df[df["param_kernel"] == "rbf"].copy()
if not df_rbf.empty:
    df_rbf = (
        df_rbf.dropna(subset=["param_C", "param_gamma"])
              .groupby(["param_gamma", "param_C"], as_index=False)
              .agg(mean_test_score=("mean_test_score", "mean"),
                   mean_train_score=("mean_train_score", "mean"))
    )

    Cs = np.sort(df_rbf["param_C"].unique())
    gammas = np.sort(df_rbf["param_gamma"].unique())

    H_val = df_rbf.pivot(index="param_gamma", columns="param_C", values="mean_test_score")
    H_trn = df_rbf.pivot(index="param_gamma", columns="param_C", values="mean_train_score")

    # --- Validation Heatmap ---
    plt.figure()
    im = plt.imshow(H_val.values, origin="lower", aspect="auto", cmap="Oranges")
    plt.colorbar(im, label="Mean CV Accuracy (Validation)")
    plt.xticks(range(len(Cs)), [str(c) for c in Cs], rotation=45, ha="right")
    plt.yticks(range(len(gammas)), [str(g) for g in gammas])
    plt.xlabel("C")
    plt.ylabel("gamma")
    plt.title("SVM RBF — Validation Accuracy")
    plt.tight_layout()
    plt.savefig("results/svm_rbf_validation_heatmap.png", dpi=300)
    plt.close()

    # --- Training Heatmap ---
    plt.figure()
    im = plt.imshow(H_trn.values, origin="lower", aspect="auto", cmap="Oranges")
    plt.colorbar(im, label="Mean CV Accuracy (Training)")
    plt.xticks(range(len(Cs)), [str(c) for c in Cs], rotation=45, ha="right")
    plt.yticks(range(len(gammas)), [str(g) for g in gammas])
    plt.xlabel("C")
    plt.ylabel("gamma")
    plt.title("SVM RBF — Training Accuracy")
    plt.tight_layout()
    plt.savefig("results/svm_rbf_training_heatmap.png", dpi=300)
    plt.close()

# %%
df_sorted = df.sort_values(by="mean_test_score", ascending=False)
df_sorted = df_sorted[['param_C', 'param_kernel', 'param_gamma', 'mean_test_score', 'mean_train_score']]
df_sorted
# Out:
#     param_C param_kernel  param_gamma  mean_test_score  mean_train_score
# 18    100.0          rbf       0.0100         0.968533          1.000000
# 8    1000.0          rbf       0.0100         0.968533          1.000000
# 3    1000.0          rbf       0.0010         0.944667          1.000000
# 12     10.0          rbf       0.0010         0.936533          0.956667
# 19   1000.0          rbf       0.0001         0.929600          0.981100
# 2       0.1       linear          NaN         0.929600          0.969517
# 15    100.0          rbf       0.0001         0.929533          0.949350
# 7       1.0       linear          NaN         0.916400          0.994333
# 4       1.0          rbf       0.0010         0.914467          0.920600
# 1      10.0          rbf       0.0001         0.911667          0.917717
# 10     10.0       linear          NaN         0.908800          0.999633
# 13    100.0       linear          NaN         0.907467          1.000000
# 14   1000.0       linear          NaN         0.907467          1.000000
# 6      10.0          rbf       0.1000         0.892067          1.000000
# 16    100.0          rbf       0.1000         0.892067          1.000000
# 17   1000.0          rbf       0.1000         0.892067          1.000000
# 5       1.0          rbf       0.1000         0.885800          0.999967
# 11      1.0          rbf       0.0001         0.855200          0.858567
# 9       0.1          rbf       0.1000         0.310400          0.340117
# 0       0.1          rbf       0.0001         0.200267          0.200800

# %%
import joblib 
params = random_search.best_params_
params
# Out:
# {'kernel': 'rbf', 'gamma': 0.01, 'C': 1000}

# %%
# C = 100 since results are identical as shown above (preventing overfitting)
model = SVC(kernel='rbf', C=100, gamma=0.01, random_state=42)

# train model 
model.fit(X_train, y_train)

# save
joblib.dump(model, "svm_model.pkl")
